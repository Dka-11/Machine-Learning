# %% [markdown]
# ## Tugas
#
# Buatlah sebuah model KMeans dengan ketentuan,
#
# 1. Gunakan data 'Mall_Customers.csv'
# 2. Tentukan fitur apa yang tepat untuk melakukan clustering (minimal 2)
# 3. Buatlah model KMeans dengan mempertimbangkan jumlah $k$ yang terbaik.

# %% [markdown]
# Import Library

# %%
# Persiapan data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('data/Mall_Customers.csv')
# Load Data
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Seleksi Fitur

x = df.iloc[:, 3:]
x
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
# Plot Data
# plot cluster berdasarkan Annual Income dan Spending Score saja

plt.scatter(x.iloc[:, 0], x.iloc[:, 1], s = 100)
# s = 100 titik / point pada plot

# %% [markdown]
# Jika $k=2$

# %%
# Buat Model KMeans

from sklearn.cluster import KMeans

# Inisiasi obyek KMeans
cl_kmeans = KMeans(n_clusters=2)

# Fit dan predict model
y_kmeans = cl_kmeans.fit_predict(x)

# %%
# Plot hasi cluster berdasarkan Annual Income dan Spending Score
plt.scatter(x.iloc[:, 0], x.iloc[:, 1], s = 100, c=y_kmeans)
# "C" -> Menghasilkan nilai cluster

# Plot centroid
centers = cl_kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5)

# %%
# Cek Nilai SSE
print(f'Nilai SSE dengan k = 2 : {cl_kmeans.inertia_}')
# Out:
# Nilai SSE dengan k = 2 : 181363.59595959607

# %% [markdown]
# Jika $k=3$

# %%
# Buat Model KMeans

from sklearn.cluster import KMeans

# Inisiasi obyek KMeans
cl_kmeans2 = KMeans(n_clusters=3)

# Fit dan predict model
y_kmeans2 = cl_kmeans2.fit_predict(x)

# %%
# Plot hasi cluster berdasarkan Annual Income dan Spending Score
plt.scatter(x.iloc[:, 0], x.iloc[:, 1], s = 100, c=y_kmeans2)
# "C" -> Menghasilkan nilai cluster

# Plot centroid
centers2 = cl_kmeans2.cluster_centers_
plt.scatter(centers2[:, 0], centers2[:, 1], c='red', s=200, alpha=0.5)

# %%
# Cek Nilai SSE
print(f'Nilai SSE dengan k = 3 : {cl_kmeans2.inertia_}')
# Out:
# Nilai SSE dengan k = 3 : 106348.37306211119

# %% [markdown]
# Jika $k=4$

# %%
# Buat Model KMeans

from sklearn.cluster import KMeans

# Inisiasi obyek KMeans
cl_kmeans3 = KMeans(n_clusters=4)

# Fit dan predict model
y_kmeans3 = cl_kmeans3.fit_predict(x)

# %%
# Plot hasi cluster berdasarkan Annual Income dan Spending Score
plt.scatter(x.iloc[:, 0], x.iloc[:, 1], s = 100, c=y_kmeans3)
# "C" -> Menghasilkan nilai cluster

# Plot centroid
centers3 = cl_kmeans3.cluster_centers_
plt.scatter(centers3[:, 0], centers3[:, 1], c='red', s=200, alpha=0.5)

# %%
# Cek Nilai SSE
print(f'Nilai SSE dengan k = 4 : {cl_kmeans3.inertia_}')
# Out:
# Nilai SSE dengan k = 4 : 73679.78903948837

# %% [markdown]
# Jika $k=5$

# %%
# Buat Model KMeans

from sklearn.cluster import KMeans

# Inisiasi obyek KMeans
cl_kmeans4 = KMeans(n_clusters=5)

# Fit dan predict model
y_kmeans4 = cl_kmeans4.fit_predict(x)

# %%
# Plot hasi cluster berdasarkan Annual Income dan Spending Score
plt.scatter(x.iloc[:, 0], x.iloc[:, 1], s = 100, c=y_kmeans4)
# "C" -> Menghasilkan nilai cluster

# Plot centroid
centers4 = cl_kmeans4.cluster_centers_
plt.scatter(centers4[:, 0], centers4[:, 1], c='red', s=200, alpha=0.5)

# %%
# Cek Nilai SSE
print(f'Nilai SSE dengan k = 5 : {cl_kmeans3.inertia_}')
# Out:
# Nilai SSE dengan k = 5 : 73679.78903948837

# %%
# Implementasi Metode Elbow

# List nilai SSE
sse = []

# Cari k terbaik dari 1-10
K = range(1,10)

# Cek nilai SSE setiap k
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(x)
    sse.append(kmeanModel.inertia_)


# Plotting the distortions
plt.figure(figsize=(8,4))
plt.plot(K, sse, "bx-")
plt.xlabel("k")
plt.ylabel("SSE")
plt.title("Metode Elbow untuk Mengetahui Jumlah k Terbaik")
plt.show()

# %% [markdown]
# Nilai SSE Setiap K

# %%
# Cek Nilai SSE setiap k
for idx, sse_val in enumerate(sse, start=1):
    print(f'k={idx}; SSE={sse_val}')
# Out:
# k=1; SSE=269981.28000000014
# k=2; SSE=181363.59595959607
# k=3; SSE=106348.37306211119
# k=4; SSE=73679.78903948837
# k=5; SSE=44448.45544793369
# k=6; SSE=37233.81451071002
# k=7; SSE=30227.60651315203
# k=8; SSE=25041.849623564838
# k=9; SSE=21838.863692828916
